# %%
問題（アヤメ）
アヤメのデータ(iris)を読み込み，アヤメの種類（3種）ごとのsepal_lengthのヒストグラムを描画せよ． （ヒント：横に並べるには facet_col引数に種類を表す列名を入れる．）

# %%
import pandas as pd
df=pd.read_csv('http://logopt.com/data/SATGPA.csv' )
y = df['GPA']
X = df[['MathSAT', 'VerbalSAT']]
from sklearn.linear_model import LinearRegression #線形回帰クラス LinearRegression のインポート
reg = LinearRegression() # 線形回帰クラスのインスタンス reg 生成
reg.fit(X, y)           # fitによる訓練
yhat = reg.predict(X)   # predictによる予測
print("y-切片= ",reg.intercept_)
print("係数 = ",reg.coef_)
SSE = ((yhat-y)**2).sum()      # Sum of Square Error
SST = ((y.mean()-y)**2).sum()  # Total Sum of Square
print("R2 =", 1-SSE/SST)       # 決定係数 R^2
print(reg.score(X,y)) #決定係数の別計算
from yellowbrick.regressor import PredictionError

visualizer = PredictionError(reg)

visualizer.fit(X, y)  
visualizer.score(X, y)  
visualizer.show();
from yellowbrick.regressor import ResidualsPlot

visualizer = ResidualsPlot(reg)

visualizer.fit(X, y)  
visualizer.score(X, y)  
visualizer.show();
# Out:
# y-切片=  2.7374715623718373
# 係数 =  [-0.00037958  0.00108557]
# R2 = 0.06645943942486443
# 0.06645943942486443

# %%
問題（住宅価格）
http://logopt.com/data/Boston.csv のBostonの住宅データを用いて回帰分析を行え． さらに結果の可視化を行え．

# %%
import pandas as pd
df=pd.read_csv('http://logopt.com/data/Boston.csv')
df.head()
y=df["medv"]
X=df.drop("medv",axis=1) 
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(X,y)
yhat=reg.predict(X)
print("y-切片=",reg.intercept_)
print("係数",reg.coef_)
print(reg.score(X,y))
from yellowbrick.regressor import PredictionError
visualizer=PredictionError(reg)
visualizer.fit(X,y)
visualizer.score(X,y)
visualizer.show();
from yellowbrick.regressor import ResidualsPlot
visualizer = ResidualsPlot(reg)
visualizer.fit(X, y)  
visualizer.score(X, y)  
visualizer.show();
# Out:
# y-切片= 36.461351871166904
# 係数 [-2.52625878e-03 -1.08762336e-01  4.80307622e-02  1.99323137e-02
#   2.70524534e+00 -1.75416021e+01  3.83922506e+00 -1.93844593e-03
#  -1.49330389e+00  3.24925469e-01 -1.15975305e-02 -9.47985187e-01
#   9.35664033e-03 -5.26183831e-01]
# 0.7414197819753732

# %%
問題（車の燃費）
http://logopt.com/data/Auto.csv の車の燃費のデータを用いて回帰分析を行え． さらに結果の可視化を行え．

# %%
import pandas as pd
df=pd.read_csv('http://logopt.com/data/Auto.csv')
y=df["mpg"]
X=df.drop(["mpg","year","origin","name"],axis=1) 
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(X,y)
yhat=reg.predict(X)
print("y-切片=",reg.intercept_)
print("係数",reg.coef_)
print(reg.score(X,y))
from yellowbrick.regressor import PredictionError
visualizer=PredictionError(reg)
visualizer.fit(X,y)
visualizer.score(X,y)
visualizer.show();
from yellowbrick.regressor import ResidualsPlot
visualizer = ResidualsPlot(reg)
visualizer.fit(X, y)  
visualizer.score(X, y)  
visualizer.show();
# Out:
# y-切片= 38.096037866844696
# 係数 [ 0.02413599 -0.36508713  0.01012755 -0.00351111 -0.00684986  0.0884215 ]
# 0.8073279088033253

# %%
問題（コンクリートの強度）
以下のコンクリートの強度の例題に対して，strength列の強度を他の列の情報から，線形回帰を用いて推定せよ． さらに結果の可視化を行え．

# %%
import pandas as pd
df=pd.read_csv('http://logopt.com/data/concrete.csv')
y=df["strength"]
X=df.drop(["strength"],axis=1) 
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(X,y)
yhat=reg.predict(X)
print("y-切片=",reg.intercept_)
print("係数",reg.coef_)
print(reg.score(X,y))
from yellowbrick.regressor import PredictionError
visualizer=PredictionError(reg)
visualizer.fit(X,y)
visualizer.score(X,y)
visualizer.show();
from yellowbrick.regressor import ResidualsPlot
visualizer = ResidualsPlot(reg)
visualizer.fit(X, y)  
visualizer.score(X, y)  
visualizer.show();
# Out:
# y-切片= -23.16375581109248
# 係数 [ 0.11978526  0.10384725  0.08794308 -0.1502979   0.29068694  0.01803018
#   0.02015446  0.11422562]
# 0.6154647342687234

# %%
問題（シェアバイク）
以下のシェアバイクのデータに対して，riders列が利用者数を，線形回帰を用いて推定せよ．ただし，date列とcasual列は除いてから回帰を行え． さらに結果の可視化を行え．

また，なぜcasual列を含めて推定をしないのか考察せよ．

# %%
import pandas as pd
df=pd.read_csv('http://logopt.com/data/bikeshare.csv')
y=df["riders"]
X=df.drop(["date","casual"],axis=1) 
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(X,y)
yhat=reg.predict(X)
print("y-切片=",reg.intercept_)
print("係数",reg.coef_)
print(reg.score(X,y))
from yellowbrick.regressor import PredictionError
visualizer=PredictionError(reg)
visualizer.fit(X,y)
visualizer.score(X,y)
visualizer.show();
from yellowbrick.regressor import ResidualsPlot
visualizer = ResidualsPlot(reg)
visualizer.fit(X, y)  
visualizer.score(X, y)  
visualizer.show();
# Out:
# y-切片= 2.2737367544323206e-13
# 係数 [-3.56749481e-15  1.50546242e-13 -1.53349555e-15 -4.36434743e-15
#   2.14097064e-15  6.18435695e-15 -8.78612233e-14 -6.21469293e-14
#   1.62600402e-13 -1.18866722e-13  2.62185022e-14 -2.47150933e-14
#   2.22044605e-15  1.00000000e+00]
# 1.0

# %%
import pandas as pd
df=pd.read_csv('http://logopt.com/data/bikeshare.csv')
df
# Out:
#              date  season  year  month  hour  holiday  weekday  workingday  \
# 0      2011-01-01       1     0      1     0        0        6           0
# 1      2011-01-01       1     0      1     1        0        6           0
# 2      2011-01-01       1     0      1     2        0        6           0
# 3      2011-01-01       1     0      1     3        0        6           0
# 4      2011-01-01       1     0      1     4        0        6           0
# ...           ...     ...   ...    ...   ...      ...      ...         ...
# 17374  2012-12-31       1     1     12    19        0        1           1
# 17375  2012-12-31       1     1     12    20        0        1           1
# 17376  2012-12-31       1     1     12    21        0        1           1
# 17377  2012-12-31       1     1     12    22        0        1           1
# 17378  2012-12-31       1     1     12    23        0        1           1
#
#        weather  temp  feelslike  humidity  windspeed  casual  registered  \
# 0            1  0.24     0.2879      0.81     0.0000       3          13
# 1            1  0.22     0.2727      0.80     0.0000       8          32
# 2            1  0.22     0.2727      0.80     0.0000       5          27
# 3            1  0.24     0.2879      0.75     0.0000       3          10
# 4            1  0.24     0.2879      0.75     0.0000       0           1
# ...        ...   ...        ...       ...        ...     ...         ...
# 17374        2  0.26     0.2576      0.60     0.1642      11         108
# 17375        2  0.26     0.2576      0.60     0.1642       8          81
# 17376        1  0.26     0.2576      0.60     0.1642       7          83
# 17377        1  0.26     0.2727      0.56     0.1343      13          48
# 17378        1  0.26     0.2727      0.65     0.1343      12          37
#
#        riders
# 0          16
# 1          40
# 2          32
# 3          13
# 4           1
# ...       ...
# 17374     119
# 17375      89
# 17376      90
# 17377      61
# 17378      49
#
# [17379 rows x 16 columns]

# %%
問題（車の価格）
http://logopt.com/data/carprice.csv から車の価格データを読み込み，線形回帰による予測を行え． また，結果を可視化せよ．

データの詳細は https://vincentarelbundock.github.io/Rdatasets/doc/DAAG/carprice.html にある．

車種(Type)，100マイル走る際のガロン数（gpm100），都市部での1ガロンあたりの走行距離（MPGcity），高速道路での１ガロン当たりの走行距離（MPGhighway）から，価格(Price)を予測せよ．

# %%
import pandas as pd
df= pd.read_csv("http://logopt.com/data/carprice.csv", index_col=0)
df = pd.get_dummies(df, drop_first=True)
y = df['Price']          
X = df.drop(['MinPrice','MaxPrice','RangePrice','RoughRange'],axis=1)
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(X,y)
yhat=reg.predict(X)
print("y-切片=",reg.intercept_)
print("係数=",reg.coef_)
print("決定係数=",reg.score(X,y))
from yellowbrick.regressor import PredictionError
visualizer=PredictionError(reg)
visualizer.fit(X,y)
visualizer.score(X,y)
visualizer.show();
from yellowbrick.regressor import ResidualsPlot
visualizer = ResidualsPlot(reg)
visualizer.fit(X, y)  
visualizer.score(X, y)  
visualizer.show();
# Out:
# y-切片= -1.0658141036401503e-14
# 係数= [ 1.00000000e+00  1.45457456e-15  9.30689296e-17  1.82443178e-17
#  -7.55789055e-16 -3.14806196e-15  6.48923108e-16 -1.36194588e-16
#  -1.95308060e-15]
# 決定係数= 1.0

# %%
問題（チップ）
チップ（tips）データに対して線形回帰を用いてもらえるチップの額 (tip) を予測せよ． また，結果を可視化せよ．

# %%
import seaborn as sns
import pandas as pd
df = sns.load_dataset('tips')
df = pd.get_dummies(df, drop_first=True)
y = df['tip']          
X = df.drop(['tip'],axis=1)
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(X,y)
yhat=reg.predict(X)
print("y-切片=",reg.intercept_)
print("係数=",reg.coef_)
print("決定係数=",reg.score(X,y))
from yellowbrick.regressor import PredictionError
visualizer=PredictionError(reg)
visualizer.fit(X,y)
visualizer.score(X,y)
visualizer.show();
from yellowbrick.regressor import ResidualsPlot
visualizer = ResidualsPlot(reg)
visualizer.fit(X, y)  
visualizer.score(X, y)  
visualizer.show();
# Out:
# y-切片= 0.5908374259513756
# 係数= [ 0.09448701  0.175992    0.03244094  0.08640832  0.1622592   0.04080082
#   0.13677854 -0.0681286 ]
# 決定係数= 0.47007812322060794
